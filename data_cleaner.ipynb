# %%
# import required libraries
import pandas as pd
import numpy as np

# load csv file (Customers)
df1 = pd.read_csv(r'C:\Users\Admin\Downloads\03_Library SystemCustomers.csv')
print(df1.head())

# Calculate completeness
cust_start_completeness = 100-(df1.isnull().mean() * 100)
print("Completeness (%):")
print(cust_start_completeness)
# Out:
#    Customer ID   Customer Name
# 0          1.0        Jane Doe
# 1          2.0      John Smith
# 2          3.0      Dan Reeves
# 3          NaN             NaN
# 4          5.0  William Holden
# Completeness (%):
# Customer ID      88.888889
# Customer Name    88.888889
# dtype: float64

# %%
# Count NaN values in each column
nan_counts = df1.isna().sum()

print(nan_counts)

# Remove NaN values
df1 = df1.dropna(how='all')
print(df1)
# Out:
# Customer ID      1
# Customer Name    1
# dtype: int64
#    Customer ID     Customer Name
# 0          1.0          Jane Doe
# 1          2.0        John Smith
# 2          3.0        Dan Reeves
# 4          5.0    William Holden
# 5          6.0     Jaztyn Forest
# 6          7.0     Jackie Irving
# 7          8.0  Matthew Stirling
# 8          9.0         Emory Ted

# %%
# Check for duplicate IDs
if df1['Customer ID'].duplicated().any():
    print(f"Check Failed: Duplicate ID found")
else:
    print(f"Check Passed: No Duplicate ID found.")

# Check for duplicate Names
if df1['Customer Name'].duplicated().any():
    print(f"Check Failed: Duplicate Name found")
else:
    print(f"Check Passed: No Duplicate Name found.")

# Calculate completeness
cust_end_completeness = 100-(df1.isnull().mean() * 100)
print("Completeness (%):")
print(cust_end_completeness)
# Out:
# Check Passed: No Duplicate ID found.
# Check Passed: No Duplicate Name found.
# Completeness (%):
# Customer ID      100.0
# Customer Name    100.0
# dtype: float64

# %%
# load csv file (Books)
df2 = pd.read_csv(r'C:\Users\Admin\Downloads\03_Library Systembook.csv')
print(df2.head())

# Calculate completeness
book_start_completeness = 100-(df2.isnull().mean() * 100)
print("Completeness (%):")
print(book_start_completeness)
# Out:
#     Id                                     Books Book checkout Book Returned  \
# 0  1.0                       Catcher in the Rye   "20/02/2023"    25/02/2023
# 1  2.0          Lord of the rings the two towers  "24/03/2023"    21/03/2023
# 2  3.0  Lord of the rings the return of the kind  "29/03/2023"    25/03/2023
# 3  4.0                                The hobbit  "02/04/2023"    25/03/2023
# 4  5.0                                     Dune   "02/04/2023"    25/03/2023
#
#   Days allowed to borrow  Customer ID
# 0                2 weeks          1.0
# 1                2 weeks          2.0
# 2                2 weeks          3.0
# 3                2 weeks          4.0
# 4                2 weeks          5.0
# Completeness (%):
# Id                        18.421053
# Books                     17.543860
# Book checkout             18.421053
# Book Returned             18.421053
# Days allowed to borrow    18.421053
# Customer ID               17.543860
# dtype: float64

# %%
# Count NaN values in each column
nan_counts = df2.isna().sum()

print(nan_counts)

# Remove NaN values
df2 = df2.dropna()
print(df2)
# Out:
# Id                        93
# Books                     94
# Book checkout             93
# Book Returned             93
# Days allowed to borrow    93
# Customer ID               94
# dtype: int64
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# 5    6.0                              Little Women  "02/04/2023"
# 6    7.0                                        IT  "10/04/2063"
# 7    8.0                                   Misery   "15/04/2023"
# 8    9.0                                  Catch 22  "15/04/2023"
# 9   10.0                              Animal Farm   "20/04/2023"
# 10  11.0                                      1984  "23/04/2023"
# 11  12.0                              Little Women  "02/04/2023"
# 12  13.0                              East of Eden  "30/04/2023"
# 13  14.0                   America Is in the Heart  "01/05/2023"
# 14  15.0                         Wuthering Heights  "01/05/2023"
# 15  16.0                                Dark Tales  "15/05/2023"
# 16  17.0                        The Bloody Chamber  "32/05/2023"
# 17  18.0                            Les Miserables  "03/06/2023"
# 18  19.0                                   Dracula  "10/06/2023"
# 19  20.0                              Frankenstein  "01/06/2023"
#
#    Book Returned Days allowed to borrow  Customer ID
# 0     25/02/2023                2 weeks          1.0
# 1     21/03/2023                2 weeks          2.0
# 2     25/03/2023                2 weeks          3.0
# 3     25/03/2023                2 weeks          4.0
# 4     25/03/2023                2 weeks          5.0
# 5     01/05/2023                2 weeks          1.0
# 6     03/04/2023                2 weeks          6.0
# 7     03/04/2023                2 weeks          7.0
# 8     16/04/2023                2 weeks          7.0
# 9     24/04/2023                2 weeks          2.0
# 10    27/04/2023                2 weeks          8.0
# 11    01/05/2023                2 weeks          1.0
# 12    05/05/2023                2 weeks          2.0
# 13    07/05/2023                2 weeks          3.0
# 14    10/05/2023                2 weeks          9.0
# 15    01/06/2023                2 weeks          2.0
# 16    04/06/2023                2 weeks          3.0
# 17    07/06/2023                2 weeks          5.0
# 18    10/07/2023                2 weeks         10.0
# 19    20/06/2023                2 weeks          2.0

# %%
# Check for duplicate IDs
if df2['Id'].duplicated().any():
    print(f"Check Failed: Duplicate ID found")
else:
    print(f"Check Passed: No Duplicate ID found.")
# Out:
# Check Passed: No Duplicate ID found.

# %%
# Capitalize each word of the book names for every row
df2['Books'] = df2['Books'].str.title()

print(df2)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher In The Rye   "20/02/2023"
# 1    2.0          Lord Of The Rings The Two Towers  "24/03/2023"
# 2    3.0  Lord Of The Rings The Return Of The Kind  "29/03/2023"
# 3    4.0                                The Hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# 5    6.0                              Little Women  "02/04/2023"
# 6    7.0                                        It  "10/04/2063"
# 7    8.0                                   Misery   "15/04/2023"
# 8    9.0                                  Catch 22  "15/04/2023"
# 9   10.0                              Animal Farm   "20/04/2023"
# 10  11.0                                      1984  "23/04/2023"
# 11  12.0                              Little Women  "02/04/2023"
# 12  13.0                              East Of Eden  "30/04/2023"
# 13  14.0                   America Is In The Heart  "01/05/2023"
# 14  15.0                         Wuthering Heights  "01/05/2023"
# 15  16.0                                Dark Tales  "15/05/2023"
# 16  17.0                        The Bloody Chamber  "32/05/2023"
# 17  18.0                            Les Miserables  "03/06/2023"
# 18  19.0                                   Dracula  "10/06/2023"
# 19  20.0                              Frankenstein  "01/06/2023"
#
#    Book Returned Days allowed to borrow  Customer ID
# 0     25/02/2023                2 weeks          1.0
# 1     21/03/2023                2 weeks          2.0
# 2     25/03/2023                2 weeks          3.0
# 3     25/03/2023                2 weeks          4.0
# 4     25/03/2023                2 weeks          5.0
# 5     01/05/2023                2 weeks          1.0
# 6     03/04/2023                2 weeks          6.0
# 7     03/04/2023                2 weeks          7.0
# 8     16/04/2023                2 weeks          7.0
# 9     24/04/2023                2 weeks          2.0
# 10    27/04/2023                2 weeks          8.0
# 11    01/05/2023                2 weeks          1.0
# 12    05/05/2023                2 weeks          2.0
# 13    07/05/2023                2 weeks          3.0
# 14    10/05/2023                2 weeks          9.0
# 15    01/06/2023                2 weeks          2.0
# 16    04/06/2023                2 weeks          3.0
# 17    07/06/2023                2 weeks          5.0
# 18    10/07/2023                2 weeks         10.0
# 19    20/06/2023                2 weeks          2.0

# %%
# Remove any leading or trailing spaces from book names
df2 = df2.map(lambda x: x.strip() if isinstance(x, str) else x)

print(df2)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                        Catcher In The Rye  "20/02/2023"
# 1    2.0          Lord Of The Rings The Two Towers  "24/03/2023"
# 2    3.0  Lord Of The Rings The Return Of The Kind  "29/03/2023"
# 3    4.0                                The Hobbit  "02/04/2023"
# 4    5.0                                      Dune  "02/04/2023"
# 5    6.0                              Little Women  "02/04/2023"
# 6    7.0                                        It  "10/04/2063"
# 7    8.0                                    Misery  "15/04/2023"
# 8    9.0                                  Catch 22  "15/04/2023"
# 9   10.0                               Animal Farm  "20/04/2023"
# 10  11.0                                      1984  "23/04/2023"
# 11  12.0                              Little Women  "02/04/2023"
# 12  13.0                              East Of Eden  "30/04/2023"
# 13  14.0                   America Is In The Heart  "01/05/2023"
# 14  15.0                         Wuthering Heights  "01/05/2023"
# 15  16.0                                Dark Tales  "15/05/2023"
# 16  17.0                        The Bloody Chamber  "32/05/2023"
# 17  18.0                            Les Miserables  "03/06/2023"
# 18  19.0                                   Dracula  "10/06/2023"
# 19  20.0                              Frankenstein  "01/06/2023"
#
#    Book Returned Days allowed to borrow  Customer ID
# 0     25/02/2023                2 weeks          1.0
# 1     21/03/2023                2 weeks          2.0
# 2     25/03/2023                2 weeks          3.0
# 3     25/03/2023                2 weeks          4.0
# 4     25/03/2023                2 weeks          5.0
# 5     01/05/2023                2 weeks          1.0
# 6     03/04/2023                2 weeks          6.0
# 7     03/04/2023                2 weeks          7.0
# 8     16/04/2023                2 weeks          7.0
# 9     24/04/2023                2 weeks          2.0
# 10    27/04/2023                2 weeks          8.0
# 11    01/05/2023                2 weeks          1.0
# 12    05/05/2023                2 weeks          2.0
# 13    07/05/2023                2 weeks          3.0
# 14    10/05/2023                2 weeks          9.0
# 15    01/06/2023                2 weeks          2.0
# 16    04/06/2023                2 weeks          3.0
# 17    07/06/2023                2 weeks          5.0
# 18    10/07/2023                2 weeks         10.0
# 19    20/06/2023                2 weeks          2.0

# %%
import re

# Function to clean date strings
def clean_date_string(s):
    if pd.isna(s):
        return s
    # Ensure string type
    s = str(s)
    # Remove surrounding quotes and spaces
    s = s.strip().strip('"').strip("'")
    return s

# Apply cleaning
df2['Book checkout'] = df2['Book checkout'].apply(clean_date_string)

# Convert to datetime
df2['Book checkout'] = pd.to_datetime(df2['Book checkout'], format='%d/%m/%Y', errors='coerce')

print(df2.head())
# Out:
#     Id                                     Books Book checkout Book Returned  \
# 0  1.0                        Catcher In The Rye    2023-02-20    25/02/2023
# 1  2.0          Lord Of The Rings The Two Towers    2023-03-24    21/03/2023
# 2  3.0  Lord Of The Rings The Return Of The Kind    2023-03-29    25/03/2023
# 3  4.0                                The Hobbit    2023-04-02    25/03/2023
# 4  5.0                                      Dune    2023-04-02    25/03/2023
#
#   Days allowed to borrow  Customer ID
# 0                2 weeks          1.0
# 1                2 weeks          2.0
# 2                2 weeks          3.0
# 3                2 weeks          4.0
# 4                2 weeks          5.0

# %%
# Convert Return date column to datetime
df2['Book Returned'] = pd.to_datetime(df2['Book Returned'], format='%d/%m/%Y', errors='coerce')

print(df2['Book Returned'].head())
# Out:
# 0   2023-02-25
# 1   2023-03-21
# 2   2023-03-25
# 3   2023-03-25
# 4   2023-03-25
# Name: Book Returned, dtype: datetime64[ns]

# %%
# Convert ID columns to integers instead of floats

import math

df2['Id'] = [int(x) for x in df2['Id']]

df2['Customer ID'] = [int(x) for x in df2['Customer ID']]

print(df2['Id'].head())
print(df2['Customer ID'].head())
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Id, dtype: int64
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Customer ID, dtype: int64

# %%
def add_days_difference_column(df, start_col, end_col, output_col="days_diff", absolute=False):
    """
    Adds a new column with the number of days between two date columns.

    Parameters:
        df (pd.DataFrame): Input DataFrame.
        start_col (str): Start date column name.
        end_col (str): End date column name.
        output_col (str): Name of the output column.
        absolute (bool): If True, returns absolute day differences.

    Returns:
        pd.DataFrame: DataFrame with the new column.
    """
    # Convert to datetime, invalid formats become NaT
    df[start_col] = pd.to_datetime(df[start_col], errors='coerce')
    df[end_col] = pd.to_datetime(df[end_col], errors='coerce')

    # Replace NaT with a default date
    #df[start_col].fillna(pd.Timestamp('2000-01-01'))
    #df[end_col].fillna(pd.Timestamp('2000-01-01'))

    # Calculate difference in days
    diff = (df[end_col] - df[start_col]).dt.days

    # Use absolute values if requested
    if absolute:
        diff = diff.abs()

    df[output_col] = diff
    return df


# Use function on Books df
if __name__ == "__main__":
    df2 = add_days_difference_column(df2, "Book checkout", "Book Returned", "days_between", absolute=True)
    print(df2)
# Out:
#     Id                                     Books Book checkout Book Returned  \
# 0    1                        Catcher In The Rye    2023-02-20    2023-02-25
# 1    2          Lord Of The Rings The Two Towers    2023-03-24    2023-03-21
# 2    3  Lord Of The Rings The Return Of The Kind    2023-03-29    2023-03-25
# 3    4                                The Hobbit    2023-04-02    2023-03-25
# 4    5                                      Dune    2023-04-02    2023-03-25
# 5    6                              Little Women    2023-04-02    2023-05-01
# 6    7                                        It    2063-04-10    2023-04-03
# 7    8                                    Misery    2023-04-15    2023-04-03
# 8    9                                  Catch 22    2023-04-15    2023-04-16
# 9   10                               Animal Farm    2023-04-20    2023-04-24
# 10  11                                      1984    2023-04-23    2023-04-27
# 11  12                              Little Women    2023-04-02    2023-05-01
# 12  13                              East Of Eden    2023-04-30    2023-05-05
# 13  14                   America Is In The Heart    2023-05-01    2023-05-07
# 14  15                         Wuthering Heights    2023-05-01    2023-05-10
# 15  16                                Dark Tales    2023-05-15    2023-06-01
# 16  17                        The Bloody Chamber           NaT    2023-06-04
# 17  18                            Les Miserables    2023-06-03    2023-06-07
# 18  19                                   Dracula    2023-06-10    2023-07-10
# 19  20                              Frankenstein    2023-06-01    2023-06-20
#
#    Days allowed to borrow  Customer ID  days_between
# 0                 2 weeks            1           5.0
# 1                 2 weeks            2           3.0
# 2                 2 weeks            3           4.0
# 3                 2 weeks            4           8.0
# 4                 2 weeks            5           8.0
# 5                 2 weeks            1          29.0
# 6                 2 weeks            6       14617.0
# 7                 2 weeks            7          12.0
# 8                 2 weeks            7           1.0
# 9                 2 weeks            2           4.0
# 10                2 weeks            8           4.0
# 11                2 weeks            1          29.0
# 12                2 weeks            2           5.0
# 13                2 weeks            3           6.0
# 14                2 weeks            9           9.0
# 15                2 weeks            2          17.0
# 16                2 weeks            3           NaN
# 17                2 weeks            5           4.0
# 18                2 weeks           10          30.0
# 19                2 weeks            2          19.0

# %%
def quarantine_dateGapIssues(df, column_name="result", output_file="cleaned.csv", removed_file="removed.csv", return_data=True):
    try:
        # Convert to numeric for safe comparison
        df[column_name] = pd.to_numeric(df[column_name], errors="coerce")
        
        # Separate negative and non-negative rows
        negative_df = df[df[column_name] < 0]
        positive_df = df[df[column_name] >= 0]

        # Save negative results
        negative_df.to_csv(removed_file, index=False)

        # Log counts
        print(f"Cleaned data kept in DataFrame: {len(positive_df)}")
        print(f"Removed negative records saved to: {removed_file} ({len(negative_df)} records removed)")

        if return_data:
            return positive_df#, negative_df

    except Exception as e:
        print(f"Error: {e}")

# %%
df2 = quarantine_dateGapIssues(
    df2,
    column_name = "days_between",
    removed_file = "removed_bookRecords.csv"
)
# Out:
# Cleaned data kept in DataFrame: 19
# Removed negative records saved to: removed_bookRecords.csv (0 records removed)

# %%
print(df2)
# Out:
#     Id                                     Books Book checkout Book Returned  \
# 0    1                        Catcher In The Rye    2023-02-20    2023-02-25
# 1    2          Lord Of The Rings The Two Towers    2023-03-24    2023-03-21
# 2    3  Lord Of The Rings The Return Of The Kind    2023-03-29    2023-03-25
# 3    4                                The Hobbit    2023-04-02    2023-03-25
# 4    5                                      Dune    2023-04-02    2023-03-25
# 5    6                              Little Women    2023-04-02    2023-05-01
# 6    7                                        It    2063-04-10    2023-04-03
# 7    8                                    Misery    2023-04-15    2023-04-03
# 8    9                                  Catch 22    2023-04-15    2023-04-16
# 9   10                               Animal Farm    2023-04-20    2023-04-24
# 10  11                                      1984    2023-04-23    2023-04-27
# 11  12                              Little Women    2023-04-02    2023-05-01
# 12  13                              East Of Eden    2023-04-30    2023-05-05
# 13  14                   America Is In The Heart    2023-05-01    2023-05-07
# 14  15                         Wuthering Heights    2023-05-01    2023-05-10
# 15  16                                Dark Tales    2023-05-15    2023-06-01
# 17  18                            Les Miserables    2023-06-03    2023-06-07
# 18  19                                   Dracula    2023-06-10    2023-07-10
# 19  20                              Frankenstein    2023-06-01    2023-06-20
#
#    Days allowed to borrow  Customer ID  days_between
# 0                 2 weeks            1           5.0
# 1                 2 weeks            2           3.0
# 2                 2 weeks            3           4.0
# 3                 2 weeks            4           8.0
# 4                 2 weeks            5           8.0
# 5                 2 weeks            1          29.0
# 6                 2 weeks            6       14617.0
# 7                 2 weeks            7          12.0
# 8                 2 weeks            7           1.0
# 9                 2 weeks            2           4.0
# 10                2 weeks            8           4.0
# 11                2 weeks            1          29.0
# 12                2 weeks            2           5.0
# 13                2 weeks            3           6.0
# 14                2 weeks            9           9.0
# 15                2 weeks            2          17.0
# 17                2 weeks            5           4.0
# 18                2 weeks           10          30.0
# 19                2 weeks            2          19.0

# %%
# Calculate final completeness
book_end_completeness = 100-(df2.isnull().mean() * 100)
print("Completeness (%):")
print(book_end_completeness)
# Out:
# Completeness (%):
# Id                        100.0
# Books                     100.0
# Book checkout             100.0
# Book Returned             100.0
# Days allowed to borrow    100.0
# Customer ID               100.0
# days_between              100.0
# dtype: float64

# %% [markdown]
# ## Output to .csv files

# %%
df1.to_csv(r'C:\Users\Admin\Desktop\DE5M5\CustomersCleaned.csv', index=False)
df2.to_csv(r'C:\Users\Admin\Desktop\DE5M5\BooksCleaned.csv', index=False)

# %%
# Show completeness variance after transformations
print("Customer Starting Completeness (%):")
print(cust_start_completeness)

print("Customer Finishing Completeness (%):")
print(cust_end_completeness)

print("Books Starting Completeness (%):")
print(book_start_completeness)

print("Books Finishing Completeness (%):")
print(book_end_completeness)
# Out:
# Customer Starting Completeness (%):
# Customer ID      88.888889
# Customer Name    88.888889
# dtype: float64
# Customer Finishing Completeness (%):
# Customer ID      100.0
# Customer Name    100.0
# dtype: float64
# Books Starting Completeness (%):
# Id                        18.421053
# Books                     17.543860
# Book checkout             18.421053
# Book Returned             18.421053
# Days allowed to borrow    18.421053
# Customer ID               17.543860
# dtype: float64
# Books Finishing Completeness (%):
# Id                        100.0
# Books                     100.0
# Book checkout             100.0
# Book Returned             100.0
# Days allowed to borrow    100.0
# Customer ID               100.0
# days_between              100.0
# dtype: float64

# %% [markdown]
# ## Export to SSMS

# %%
from sqlalchemy import create_engine
import urllib
import sys

# SQL Server connection details (edit these)
server = r'STUDENT01'      
database = 'libraryProject'

# %% [markdown]
# ### Load Customers data

# %%
# Define table for Customers data
table_name = 'Customers'

try:
    # Build ODBC connection string
    connection_string = (
        f"DRIVER={{ODBC Driver 17 for SQL Server}};"
        f"SERVER={server};"
        f"DATABASE={database};"
        f"Trusted_Connection=yes;"
    )

    # Encode for SQLAlchemy
    connection_uri = "mssql+pyodbc:///?odbc_connect=" + urllib.parse.quote_plus(connection_string)

    # Create SQLAlchemy engine
    engine = create_engine(connection_uri, fast_executemany=True)

    # Export DataFrame to SQL Server
    df1.to_sql(
        name=table_name,
        con=engine,
        if_exists='replace',  # 'replace' overwrites, 'append' adds rows
        index=False
    )

    print(f"✅ DataFrame successfully exported to table '{table_name}' in database '{database}'.")
    print("You can now view it in SSMS.")

except Exception as e:
    print("❌ Failed to export DataFrame to SQL Server.")
    print("Error details:", e)
    sys.exit(1)
# Out:
# ✅ DataFrame successfully exported to table 'Customers' in database 'libraryProject'.
# You can now view it in SSMS.

# %% [markdown]
# ### Load Books data

# %%
# Define table for Books data
table_name = 'Books'

try:
    # Build ODBC connection string
    connection_string = (
        f"DRIVER={{ODBC Driver 17 for SQL Server}};"
        f"SERVER={server};"
        f"DATABASE={database};"
        f"Trusted_Connection=yes;"
    )

    # Encode for SQLAlchemy
    connection_uri = "mssql+pyodbc:///?odbc_connect=" + urllib.parse.quote_plus(connection_string)

    # Create SQLAlchemy engine
    engine = create_engine(connection_uri, fast_executemany=True)

    # Export DataFrame to SQL Server
    df2.to_sql(
        name=table_name,
        con=engine,
        if_exists='replace',  # 'replace' overwrites, 'append' adds rows
        index=False
    )

    print(f"✅ DataFrame successfully exported to table '{table_name}' in database '{database}'.")
    print("You can now view it in SSMS.")

except Exception as e:
    print("❌ Failed to export DataFrame to SQL Server.")
    print("Error details:", e)
    sys.exit(1)
# Out:
# ✅ DataFrame successfully exported to table 'Books' in database 'libraryProject'.
# You can now view it in SSMS.
